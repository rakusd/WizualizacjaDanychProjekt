# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %%
font = {'family' : 'normal',
        'size'   : 14}

matplotlib.rc('font', **font)

# %%
def show_values_on_bars(axs, sufix='', height=0.03, precision=1):
    def _show_on_single_plot(ax):        
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + height
            value = ('{:.'+str(precision)+'f}'+sufix).format(p.get_height())
            if p.get_height()>0:
                ax.text(_x, _y, value, ha="center") 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %%
#8

# %%
X = ['APOSTEL', 'RGT Kilimanjaro', 'Patras', 'Formacja']
Y = [103,99,99,98]
title = "APOSTEL - plon ziarna na tle wzorca pszenicy jakościowej [A] COBORU"
ylabel = "% wzorca"

# %%
plt.figure(figsize=(12,7))
ax = sns.barplot(X, Y)
ax.set_title(title)
ax.set_ylabel(ylabel)
ax.get_figure().savefig("img8_correct_2.png")
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
colors = ['#df007f', '#6f6d6e', '#6f6d6e', '#6f6d6e']
plt.figure(figsize=(12,7))
ax = sns.barplot(X, Y, palette=colors)
show_values_on_bars(ax, height=1, precision=0)
ax.set_title(title)
ax.set_ylabel(ylabel)
ax.get_figure().savefig("img8_correct.png")

# %%
#9

# %%
X = list(reversed(['ZDECYDOWANIE TAK', 'RACZEJ TAK', 'RACZEJ NIE', 'ZDECYDOWANIE NIE', 'NIE WIEM, TRUDNO POWIEDZIEĆ']))
Y = list(reversed([48,7,12,29,4]))
colors = list(reversed(["#0098de", "#93c7e5","#cdcdcd","#999999","#ecaea9"]))
title = "Gdyby wybory do sejmu odbywały się w najbliższą niedzielę, to czy wziąłbyś w nich udział?"

# %%
plt.figure(figsize=(12,7))
ax = plt.pie(Y, labels=X, autopct='%1.0f%%', colors=colors, startangle=-90)
z = plt.title(title)#' '.join([r"$\bf{"+w+"}$" for w in title.split()]))
plt.savefig("img9_correct.png")

# %%
#10

# %%
#bad

# %%
X = [str(r)+' r.' for r in range(2014,2020)]+['2017-2020 r.']
Y = [0,0,0,0.4,1.4,3.1,6.3]
color = '#fc006c'
title = "Podwyżka wynagrodzeń nauczycieli finansowana z budżetu państwa"
ylabel = "kwota [mld zł]"

# %%
plt.figure(figsize=(12,7))
ax = sns.barplot(X, Y, color=color)
ax.set_title(title)
ax.set_ylabel(ylabel)
show_values_on_bars(ax, sufix=" mld zł")
ax.get_figure().savefig("img10_incorrect.png")

# %%
#good

# %%
X = [str(r)+' r.' for r in range(2014,2021)]
Y = [0,0,0,0.4,1.4,3.1,1.4]
color = '#fc006c'
title = "Podwyżka wynagrodzeń nauczycieli finansowana z budżetu państwa"
ylabel = "kwota [mld zł]"

# %%
plt.figure(figsize=(12,7))
ax = sns.barplot(X, Y, color=color)
ax.set_title(title)
ax.set_ylabel(ylabel)
show_values_on_bars(ax, sufix=" mld zł")
ax.get_figure().savefig("img10_correct.png")
